# %%
from dotenv import load_dotenv
import os

from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage

load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

llm = ChatOpenAI(model="gpt-3.5-turbo")

# Structured memory
chat_history = []

# Optional system message
system_message = SystemMessage(content="You are a helpful assistant.")

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        break

    # Add user message to memory
    chat_history.append(HumanMessage(content=user_input))

    # Send full conversation to LLM
    response = llm.invoke([system_message] + chat_history)

    # Print response
    print("Bot:", response.content)

    # Add assistant response to memory
    chat_history.append(AIMessage(content=response.content))
# Out:
# Bot: Hello! How can I assist you today?
# Bot: Today is October 18, 2021. How can I help you further?
# Bot: Nice to meet you, Arihant! How can I assist you today?
# Bot: I am a virtual assistant here to help you. You can refer to me as your helpful assistant. How can I assist you today?
# Bot: Your name is Arihant. How can I assist you further, Arihant?
# Bot: The first thing you told me was "hi". How can I assist you further, Arihant?
# Bot: After saying "hi", you mentioned that your name is Arihant. How can I assist you today, Arihant?
# Bot: My apologies for the oversight. Yes, you did ask for the date. Today is October 18, 2021. Is there anything else I can assist you with, Arihant?
# Bot: If you have any more questions or need assistance in the future, feel free to ask. Have a great day, Arihant!

# %%
chat_history
# Out:
# [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='Hello! How can I assist you today?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='What is the date today', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='Today is October 18, 2021. How can I help you further?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='My name is Arihant', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='Nice to meet you, Arihant! How can I assist you today?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='What is your nae', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='I am a virtual assistant here to help you. You can refer to me as your helpful assistant. How can I assist you today?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='what was my name', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='Your name is Arihant. How can I assist you further, Arihant?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='what was the first thing i told you', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='The first thing you told me was "hi". How can I assist you further, Arihant?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='after Hi ?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='After saying "hi", you mentioned that your name is Arihant. How can I assist you today, Arihant?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content="Didn't I ask temp ?", additional_kwargs={}, response_metadata={}),
#  AIMessage(content='My apologies for the oversight. Yes, you did ask for the date. Today is October 18, 2021. Is there anything else I can assist you with, Arihant?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='If you have any more questions or need assistance in the future, feel free to ask. Have a great day, Arihant!', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]
