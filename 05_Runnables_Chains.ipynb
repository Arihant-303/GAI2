# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

llm = ChatOpenAI(model = "gpt-4o-mini")

# %%
prompt = ChatPromptTemplate.from_template("""
Explain {topic} in simple terms
""")

# %%
#Sequential Runnable
chain = prompt | llm

# %%
response = chain.invoke({"topic": "neural Networks"})
print(response.content)
# Out:
# Sure! Think of a neural network as a simplified model of how our brains work, designed to help machines learn from data. Here’s a simple breakdown:
#
# 1. **Neurons**: Just like our brain has neurons that send signals to each other, a neural network has small units called "neurons" that process information.
#
# 2. **Layers**: Neurons are organized into layers. The first layer takes in input data (like images, text, or numbers). The next layers process this data, and the final layer produces an output (like predicting a number or classifying an object).
#
# 3. **Connections**: Neurons in one layer are connected to neurons in the next layer. Each connection has a weight, which indicates how much influence one neuron has on another. These weights are adjusted during learning.
#
# 4. **Learning**: When we train a neural network, we provide it with examples (like photos of cats and dogs). The network makes predictions and learns from its mistakes by adjusting the weights based on how far off its predictions were from the actual answers.
#
# 5. **Activation Function**: Each neuron uses an activation function to decide whether to "fire" (send a signal) based on the input it receives. This helps the network learn complex patterns in the data.
#
# In summary, a neural network is a system of connected units that learn to make decisions or predictions based on examples we give it, much like how humans learn from experience.
