# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableParallel

llm = ChatOpenAI(model = "gpt-4o-mini")

# %%
prompt1 = ChatPromptTemplate.from_template(
    "Explain {topic} in 20 words"
)

prompt2 = ChatPromptTemplate.from_template(
    "Explain {topic} in detail"
)

# %%
chain = RunnableParallel(
    short_explanation = prompt1 | llm,
    detailed_explanation = prompt2 | llm
)

# %%
result = chain.invoke({"topic": "DBSCAN"})
print(result)
# Out:
# {'short_explanation': AIMessage(content='DBSCAN (Density-Based Spatial Clustering of Applications with Noise) groups dense regions of data, identifying clusters and outliers effectively.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 14, 'total_tokens': 40, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DEDHybVRuZERNbUvjGIcun66T0j2l', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ca41f-5fc9-7cc3-a2aa-0018b5a05f8e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 26, 'total_tokens': 40, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'detailed_explanation': AIMessage(content='DBSCAN (Density-Based Spatial Clustering of Applications with Noise) is a popular clustering algorithm used in machine learning and data mining. It is particularly effective for discovering clusters of varying shapes and sizes in spatial data and is robust to noise and outliers. Here’s a detailed explanation of how DBSCAN works, its parameters, strengths, weaknesses, and typical applications.\n\n### How DBSCAN Works\n\nDBSCAN is based on the idea of density: it identifies clusters as regions of high density separated by regions of low density. The process to form clusters can be outlined as follows:\n\n1. **Parameters**:\n   - **Epsilon (ε)**: The maximum distance between two samples for one to be considered as in the neighborhood of the other. This defines the radius of the neighborhood.\n   - **MinPts**: The minimum number of points required to form a dense region (i.e., a cluster). A common heuristic is to set MinPts to 2 * the number of dimensions in the dataset.\n\n2. **Core Points, Border Points, and Noise**:\n   - **Core Point**: A point that has at least MinPts points within its ε neighborhood.\n   - **Border Point**: A point that is not a core point but is within the ε neighborhood of a core point.\n   - **Noise Point**: A point that is neither a core point nor a border point.\n\n3. **Clustering Process**:\n   - Start with an arbitrary point not yet visited. Retrieve its neighbors (all points within ε distance).\n   - If the number of neighbors is greater than or equal to MinPts, a new cluster is formed, and that point is marked as a core point.\n   - Expand the cluster by recursively including all neighbors of core points (either core points or border points) until no more points can be added.\n   - If the initial point does not have enough neighbors, it is labeled as noise.\n   - Repeat the steps for all points in the dataset until all points are visited.\n\n### Example\n\nConsider a simple dataset of 2D points. You could visualize DBSCAN by:\n1. Choosing an ε distance (e.g., 0.5).\n2. Selecting a point and counting the number of neighboring points within this distance.\n3. If sufficient neighbors are found based on MinPts, a cluster is initiated.\n\n### Strengths of DBSCAN\n\n1. **Handling Noise**: It can effectively identify outliers and noise as points that do not belong to any cluster.\n2. **Arbitrary Shapes**: DBSCAN can find clusters of varying shapes and sizes, which is a limitation for many centroid-based clustering methods like K-means.\n3. **No Need for Predefined Number of Clusters**: Unlike K-means, DBSCAN does not require specifying the number of clusters in advance.\n\n### Weaknesses of DBSCAN\n\n1. **Parameter Sensitivity**: The performance of DBSCAN is highly dependent on the choice of ε and MinPts. Incorrectly setting these parameters can lead to poor clustering results.\n2. **Varying Densities**: DBSCAN struggles with datasets containing c ...

# %%
result.keys()
# Out:
# dict_keys(['short_explanation', 'detailed_explanation'])

# %%
result["detailed_explanation"]
# Out:
# AIMessage(content='DBSCAN (Density-Based Spatial Clustering of Applications with Noise) is a popular clustering algorithm used in machine learning and data mining. It is particularly effective for discovering clusters of varying shapes and sizes in spatial data and is robust to noise and outliers. Here’s a detailed explanation of how DBSCAN works, its parameters, strengths, weaknesses, and typical applications.\n\n### How DBSCAN Works\n\nDBSCAN is based on the idea of density: it identifies clusters as regions of high density separated by regions of low density. The process to form clusters can be outlined as follows:\n\n1. **Parameters**:\n   - **Epsilon (ε)**: The maximum distance between two samples for one to be considered as in the neighborhood of the other. This defines the radius of the neighborhood.\n   - **MinPts**: The minimum number of points required to form a dense region (i.e., a cluster). A common heuristic is to set MinPts to 2 * the number of dimensions in the dataset.\n\n2. **Core Points, Border Points, and Noise**:\n   - **Core Point**: A point that has at least MinPts points within its ε neighborhood.\n   - **Border Point**: A point that is not a core point but is within the ε neighborhood of a core point.\n   - **Noise Point**: A point that is neither a core point nor a border point.\n\n3. **Clustering Process**:\n   - Start with an arbitrary point not yet visited. Retrieve its neighbors (all points within ε distance).\n   - If the number of neighbors is greater than or equal to MinPts, a new cluster is formed, and that point is marked as a core point.\n   - Expand the cluster by recursively including all neighbors of core points (either core points or border points) until no more points can be added.\n   - If the initial point does not have enough neighbors, it is labeled as noise.\n   - Repeat the steps for all points in the dataset until all points are visited.\n\n### Example\n\nConsider a simple dataset of 2D points. You could visualize DBSCAN by:\n1. Choosing an ε distance (e.g., 0.5).\n2. Selecting a point and counting the number of neighboring points within this distance.\n3. If sufficient neighbors are found based on MinPts, a cluster is initiated.\n\n### Strengths of DBSCAN\n\n1. **Handling Noise**: It can effectively identify outliers and noise as points that do not belong to any cluster.\n2. **Arbitrary Shapes**: DBSCAN can find clusters of varying shapes and sizes, which is a limitation for many centroid-based clustering methods like K-means.\n3. **No Need for Predefined Number of Clusters**: Unlike K-means, DBSCAN does not require specifying the number of clusters in advance.\n\n### Weaknesses of DBSCAN\n\n1. **Parameter Sensitivity**: The performance of DBSCAN is highly dependent on the choice of ε and MinPts. Incorrectly setting these parameters can lead to poor clustering results.\n2. **Varying Densities**: DBSCAN struggles with datasets containing clusters of differing densities. In such situations, a single ε may not capture all clusters effectively.\n3. **High-Dimensional Data**: In high-dimensional spaces, the notion of density becomes less meaningful due to the curse of dimensionality, which can make DBSCAN less effective.\n\n### Applications of DBSCAN\n\n1. **Spatial Data Analysis**: Commonly used in geography and astronomy to identify spatial clusters.\n2. **Image Processing**: For object detection or feature extraction from images.\n3. **Anomaly Detection**: Applied to identify anomalies or outliers in various types of data, including network intrusion detection.\n4. **Market Segmentation**: Helps in customer segmentation based on purchasing behavior.\n\n### Conclusion\n\nDBSCAN is a valuable algorithm for clustering tasks, particularly when dealing with spatial data and noise. Understanding its mechanics, strengths, and limitations enables data scientists and analysts to apply it effectively in various real-world scenarios. Adjusting its parameters requires careful consideration, a ...
