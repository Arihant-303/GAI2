# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm = ChatOpenAI(model="gpt-3.5-turbo")

prompt = ChatPromptTemplate.from_template(
    "Explain {topic} in simple words."
)

chain = prompt | llm | StrOutputParser()

response = chain.invoke({"topic": "Machine Learning"})
print(response)
# Out:
# Machine learning is a type of technology that allows computers to learn and make decisions without human intervention. It works by analyzing data and identifying patterns, which it uses to make predictions or decisions. In simpler terms, machine learning is like teaching a computer to think and make decisions on its own based on the data it is given.
